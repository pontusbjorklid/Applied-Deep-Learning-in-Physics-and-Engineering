# %% [markdown]
# # Exercise 6.3: Neural Networks in Keras

# %%
import numpy as np
import matplotlib.pyplot as plt

# See https://keras.io/
# for extennsive documentation
import tensorflow as tf
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras import regularizers

# %% [markdown]
# Let us visit the problem of wine quality prediction previously encountered one final time. After linear regression and a self-made network, we can now explore the comfort provided by the Keras library.

# %%
# The code snippet below is responsible for downloading the dataset to
# Google. You can directly download the file using the link
# if you work with a local anaconda setup
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv

# %%
# load all examples from the file
data = np.genfromtxt('winequality-white.csv',delimiter=";",skip_header=1)

print("data:", data.shape)

# Prepare for proper training
np.random.shuffle(data) # randomly sort examples

# normalize features
for i in range(11):
    data[:,i] = (data[:,i]-np.mean(data[:,i]))/np.std(data[:,i])

# take the first 3000 examples for training
X_train = data[:3000,:11] # all features except last column
y_train = data[:3000,11]  # quality column

# and the remaining examples for testing
X_test = data[3000:,:11] # all features except last column
y_test = data[3000:,11] # quality column

print("First example:")
print("Features:", X_train[0])
print("Quality:", y_train[0])
# Out:
# data: (4898, 12)
# First example:
# Features: [-0.4204731   0.11667379 -0.1999175  -0.9250474  -0.4931102  -0.6649702
#  -1.39692757 -1.16945584  0.54133365  1.75397237  0.71981845]
# Quality: 7.0

# %% [markdown]
# Below is the simple network from exercise 4.1 implemented using Keras. In addition to the network we define the loss function and optimiser.

# %%
# See: https://keras.io/api/models/sequential/ and
# https://keras.io/api/layers/core_layers/dense/
# We can use the Sequential class to very easiliy
# build a simple architecture
model = Sequential()
# 11 inputs, 20 outputs, relu
model.add(Dense(256, kernel_regularizer=regularizers.l2(0.01), input_dim=11, activation='relu'))
model.add(Dense(128, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
# 20 inputs (automatically detected by Keras), 1 output, linear activation
model.add(Dense(1, activation='linear'))

adam = keras.optimizers.Adam(learning_rate=0.01)

# Set loss function and optimiser algorithm
model.compile(loss='mse',  # mean squared error
              optimizer= adam, # stochastic gradient descent with momentum
              #optimizer='sgd' # stochastic gradient descent
              metrics=['mse'])

early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=1, restore_best_weights=True)

# %% [markdown]
# # Training and evaluation below
#
# The code below trains the network for 5 epochs using the loss function and optimiser defined above. Each example is individually passed to the network

# %%
history = model.fit(X_train,
                    y_train,
                    validation_data=(X_test, y_test),
                    epochs=100, 
                    batch_size=64,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 2s 12ms/step - loss: 5.8690 - mse: 3.7722 - val_loss: 2.9968 - val_mse: 1.6670
# Epoch 2/100
# 47/47 [==============================] - 0s 7ms/step - loss: 1.8071 - mse: 0.8723 - val_loss: 1.2690 - val_mse: 0.6354
# Epoch 3/100
# 47/47 [==============================] - 0s 6ms/step - loss: 1.0673 - mse: 0.5870 - val_loss: 1.2255 - val_mse: 0.8612
# Epoch 4/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.9419 - mse: 0.6491 - val_loss: 0.9220 - val_mse: 0.6875
# Epoch 5/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7980 - mse: 0.5957 - val_loss: 0.7200 - val_mse: 0.5481
# Epoch 6/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7886 - mse: 0.6331 - val_loss: 0.7579 - val_mse: 0.6182
# Epoch 7/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7621 - mse: 0.6350 - val_loss: 0.8251 - val_mse: 0.7101
# Epoch 8/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6967 - mse: 0.5867 - val_loss: 0.6623 - val_mse: 0.5600
# Epoch 9/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6461 - mse: 0.5499 - val_loss: 0.6250 - val_mse: 0.5354
# Epoch 10/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6433 - mse: 0.5568 - val_loss: 0.6006 - val_mse: 0.5209
# Epoch 11/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6280 - mse: 0.5500 - val_loss: 0.6337 - val_mse: 0.5561
# Epoch 12/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6269 - mse: 0.5544 - val_loss: 0.5889 - val_mse: 0.5192
# Epoch 13/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6357 - mse: 0.5686 - val_loss: 0.5655 - val_mse: 0.4995
# Epoch 14/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5982 - mse: 0.5334 - val_loss: 0.6008 - val_mse: 0.5338
# Epoch 15/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6139 - mse: 0.5527 - val_loss: 0.5942 - val_mse: 0.5358
# Epoch 16/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.6192 - mse: 0.5613 - val_loss: 0.5840 - val_mse: 0.5289
# Epoch 17/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.7154 - mse: 0.6591 - val_loss: 0.6095 - val_mse: 0.5516
# Epoch 18/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5968 - mse: 0.5393 - val_loss: 0.6833 - val_mse: 0.6305
# Epoch 19/100
# 47/47 [==============================] - 0s 7ms/step - loss: 0.5957 - mse: 0.5412 - val_loss: 0.5766 - val_mse: 0.5261
# Epoch 20/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5869 - mse: 0.5364 - val_loss: 0.5745 - val_mse: 0.5247
# Epoch 21/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5775 - mse: 0.5258 - val_loss: 0.5730 - val_mse: 0.5225
# Epoch 22/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5897 - mse: 0.5407 - val_loss: 0.5729 - val_mse: 0.5253
# Epoch 23/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.5767 - mse: 0.5268 - val_loss: 0.5505 - val_mse: 0.5020
# Epoch 24/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5844 - mse: 0.5348 - val_loss: 0.5894 - val_mse: 0.5419
# Epoch 25/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5750 - mse: 0.5263 - val_loss: 0.5758 - val_mse: 0.5275
# Epoch 26/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6572 - mse: 0.6089 - val_loss: 0.6390 - val_mse: 0.5921
# Epoch 27/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.6095 - mse: 0.5582 - val_loss: 0.6010 - val_mse: 0.5506
# Epoch 28/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5787 - mse: 0.5298 - val_loss: 0.5646 - val_mse: 0.5156
# Epoch 29/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5675 - mse: 0.5217 - val_loss: 0.5482 - val_mse: 0.5015
# Epoch 30/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5723 - mse: 0.5245 - val_loss: 0.5560 - val_mse: 0.5089
# Epoch 31/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5588 - mse: 0.5116 - val_loss: 0.5670 - val_mse: 0.5205
# Epoch 32/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5694 - mse: 0.5218 - val_loss: 0.5481 - val_mse: 0.5042
# Epoch 33/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5632 - mse: 0.5163 - val_loss: 0.5622 - val_mse: 0.5157
# Epoch 34/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5652 - mse: 0.5192 - val_loss: 0.5707 - val_mse: 0.5214
# Epoch 35/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5555 - mse: 0.5082 - val_loss: 0.5486 - val_mse: 0.5007
# Epoch 36/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5587 - mse: 0.5107 - val_loss: 0.5411 - val_mse: 0.4946
# Epoch 37/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.5769 - mse: 0.5294 - val_loss: 0.6121 - val_mse: 0.5639
# Epoch 38/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5682 - mse: 0.5211 - val_loss: 0.5776 - val_mse: 0.5294
# Epoch 39/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5728 - mse: 0.5257 - val_loss: 0.6088 - val_mse: 0.5623
# Epoch 40/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5616 - mse: 0.5143 - val_loss: 0.5438 - val_mse: 0.4997
# Epoch 41/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5608 - mse: 0.5135 - val_loss: 0.5400 - val_mse: 0.4938
# Epoch 42/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5656 - mse: 0.5192 - val_loss: 0.5667 - val_mse: 0.5218
# Epoch 43/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5593 - mse: 0.5148 - val_loss: 0.5380 - val_mse: 0.4925
# Epoch 44/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5547 - mse: 0.5091 - val_loss: 0.5366 - val_mse: 0.4892
# Epoch 45/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5502 - mse: 0.5044 - val_loss: 0.5467 - val_mse: 0.5003
# Epoch 46/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5664 - mse: 0.5203 - val_loss: 0.5479 - val_mse: 0.5015
# Epoch 47/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5814 - mse: 0.5358 - val_loss: 0.6013 - val_mse: 0.5549
# Epoch 48/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5647 - mse: 0.5182 - val_loss: 0.5441 - val_mse: 0.4968
# Epoch 49/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5418 - mse: 0.4943 - val_loss: 0.5375 - val_mse: 0.4929
# Epoch 50/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5574 - mse: 0.5132 - val_loss: 0.5305 - val_mse: 0.4859
# Epoch 51/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5436 - mse: 0.4970 - val_loss: 0.5398 - val_mse: 0.4955
# Epoch 52/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5472 - mse: 0.5027 - val_loss: 0.5435 - val_mse: 0.4987
# Epoch 53/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5490 - mse: 0.5043 - val_loss: 0.5447 - val_mse: 0.5010
# Epoch 54/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5538 - mse: 0.5084 - val_loss: 0.5309 - val_mse: 0.4855
# Epoch 55/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5469 - mse: 0.5017 - val_loss: 0.5479 - val_mse: 0.5028
# Epoch 56/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5622 - mse: 0.5192 - val_loss: 0.5642 - val_mse: 0.5198
# Epoch 57/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5482 - mse: 0.5041 - val_loss: 0.5529 - val_mse: 0.5085
# Epoch 58/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5419 - mse: 0.4972 - val_loss: 0.5371 - val_mse: 0.4937
# Epoch 59/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5601 - mse: 0.5164 - val_loss: 0.5789 - val_mse: 0.5363
# Epoch 60/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5448 - mse: 0.4997 - val_loss: 0.5325 - val_mse: 0.4889
# Epoch 61/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5541 - mse: 0.5109 - val_loss: 0.5266 - val_mse: 0.4833
# Epoch 62/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5611 - mse: 0.5192 - val_loss: 0.5420 - val_mse: 0.5001
# Epoch 63/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5391 - mse: 0.4967 - val_loss: 0.5344 - val_mse: 0.4902
# Epoch 64/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5443 - mse: 0.5014 - val_loss: 0.5796 - val_mse: 0.5351
# Epoch 65/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5662 - mse: 0.5232 - val_loss: 0.5331 - val_mse: 0.4885
# Epoch 66/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5386 - mse: 0.4951 - val_loss: 0.5366 - val_mse: 0.4933
# Epoch 67/100
# 47/47 [==============================] - 0s 7ms/step - loss: 0.5499 - mse: 0.5075 - val_loss: 0.5359 - val_mse: 0.4938
# Epoch 68/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5377 - mse: 0.4952 - val_loss: 0.5274 - val_mse: 0.4855
# Epoch 69/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5413 - mse: 0.4985 - val_loss: 0.5294 - val_mse: 0.4890
# Epoch 70/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5412 - mse: 0.4993 - val_loss: 0.5310 - val_mse: 0.4896
# Epoch 71/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5384 - mse: 0.4960 - val_loss: 0.5498 - val_mse: 0.5075
# Epoch 72/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5484 - mse: 0.5064 - val_loss: 0.5396 - val_mse: 0.4968
# Epoch 73/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5488 - mse: 0.5064 - val_loss: 0.5343 - val_mse: 0.4934
# Epoch 74/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5463 - mse: 0.5044 - val_loss: 0.5382 - val_mse: 0.4973
# Epoch 75/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5488 - mse: 0.5072 - val_loss: 0.5543 - val_mse: 0.5104
# Epoch 76/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5411 - mse: 0.4988 - val_loss: 0.5428 - val_mse: 0.5003
# Epoch 77/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5532 - mse: 0.5105 - val_loss: 0.5425 - val_mse: 0.5006
# Epoch 78/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5451 - mse: 0.5031 - val_loss: 0.5524 - val_mse: 0.5127
# Epoch 79/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5431 - mse: 0.5017 - val_loss: 0.5257 - val_mse: 0.4835
# Epoch 80/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.5407 - mse: 0.4995 - val_loss: 0.5412 - val_mse: 0.4985
# Epoch 81/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5504 - mse: 0.5085 - val_loss: 0.5386 - val_mse: 0.4970
# Epoch 82/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.5388 - mse: 0.4972 - val_loss: 0.5301 - val_mse: 0.4900
# Epoch 83/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5467 - mse: 0.5049 - val_loss: 0.5802 - val_mse: 0.5383
# Epoch 84/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5528 - mse: 0.5124 - val_loss: 0.5435 - val_mse: 0.5018
# Epoch 85/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5397 - mse: 0.4986 - val_loss: 0.5288 - val_mse: 0.4880
# Epoch 86/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5588 - mse: 0.5176 - val_loss: 0.6014 - val_mse: 0.5621
# Epoch 87/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5452 - mse: 0.5050 - val_loss: 0.5571 - val_mse: 0.5160
# Epoch 88/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5440 - mse: 0.5036 - val_loss: 0.5420 - val_mse: 0.5015
# Epoch 89/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5430 - mse: 0.5019 - val_loss: 0.5340 - val_mse: 0.4952
# Epoch 90/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5377 - mse: 0.4987 - val_loss: 0.5260 - val_mse: 0.4855
# Epoch 91/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5482 - mse: 0.5083 - val_loss: 0.5424 - val_mse: 0.5034
# Epoch 92/100
# 47/47 [==============================] - 0s 7ms/step - loss: 0.5525 - mse: 0.5136 - val_loss: 0.5313 - val_mse: 0.4896
# Epoch 93/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5323 - mse: 0.4924 - val_loss: 0.5276 - val_mse: 0.4883
# Epoch 94/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5439 - mse: 0.5052 - val_loss: 0.5240 - val_mse: 0.4854
# Epoch 95/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5365 - mse: 0.4964 - val_loss: 0.5675 - val_mse: 0.5271
# Epoch 96/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5469 - mse: 0.5080 - val_loss: 0.5304 - val_mse: 0.4916
# Epoch 97/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5369 - mse: 0.4978 - val_loss: 0.5281 - val_mse: 0.4895
# Epoch 98/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5480 - mse: 0.5078 - val_loss: 0.5609 - val_mse: 0.5220
# Epoch 99/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5406 - mse: 0.5007 - val_loss: 0.5444 - val_mse: 0.5036
# Epoch 100/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.5641 - mse: 0.5254 - val_loss: 0.5822 - val_mse: 0.5435

# %%
# The history object returned by the model training above
# contains the values of the loss function (the mean-squared-error)
# at different epochs
# We discard the first epoch as the loss value is very high,
# obscuring the rest of the distribution
train_loss = history.history["loss"][1:]
test_loss = history.history["val_loss"][1:]

# %%
# Prepare and plot loss over time
plt.plot(train_loss,label="train")
plt.plot(test_loss,label="test")
plt.legend()
plt.xlabel("Epoch-1")
plt.ylabel("Loss")
plt.show()

# %%
# After the training:

# Prepare scatter plot
y_pred = model.predict(X_test)[:,0]
jitter = 0.2
y_pred_jitter = y_pred + np.random.uniform(-jitter,jitter,size=y_pred.shape)
y_test_jitter = y_test + np.random.uniform(-jitter,jitter,size=y_test.shape)

print("Correlation coefficient:", np.corrcoef(y_pred,y_test)[0,1])
plt.scatter(y_pred_jitter,y_test_jitter, alpha = 0.5)
plt.title("Scatter Plot with Jitter")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
#  1/60 [..............................] - ETA: 1s
# 60/60 [==============================] - 0s 3ms/step
# Correlation coefficient: 0.6071833792584829

# %% [markdown]
# # Problems
#
# * Use the notebook as starting point. It already contains the simple network from Exercise 4.1 implemented in Keras.
#
# * Currently, SGD is used without momentum. Try training with a momentum term. Replace SGD with the Adam optimizer and train using that. (See: https://keras.io/api/optimizers/)
# * Add two more hidden layers to the network (you can choose the number of nodes but make sure to apply the ReLu activation function after each) and train again.
# * Test differet numbers of examples (i.e. change the batch batch size) to be simulataneously used by the network.
# * (bonus) optimize the network architecture to get the best correlation coefficient. (Let's see who gets the most out of the data).

# %% [markdown]
# Generall Comment
